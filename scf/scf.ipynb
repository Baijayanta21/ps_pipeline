# %%
import numpy as np
import scf
# Out:
# Imported SCF, Import Time : 21/05/26 | 03:01:38 PM

# %%
GV = np.load("/home/baijayanta/GV_7200_pool.npy") # GV array
print(f"{GV.shape = }")
# Out:
# GV.shape = (2, 46438, 768)

# %%
SM = 2 # smoothing scale in MHz
NW = int(SM/0.04)
print(f"{NW = }")
NW = 50
# perform SCF
GV_filtered = scf.doscf(GV, SM, window = 'hann', method = 'fft')
print(f"{GV_filtered.shape = }") # 768-2*NW
# Out:
# NW = 50
# <============= Performing SCF =============>
# <=== Start Time: 21/05/26 | 03:01:39 PM ===>
# Convoluting kernel : fft
# Window function    : Hanning
# Smoothing scale    : 2 MHz
# <=== End Time  : 21/05/26 | 03:01:41 PM ===>
# <=== Elapsed   : 00:00:02.14, 2.142 seconds.
# <================ Done SCF ================>
# GV_filtered.shape = (2, 46438, 668)
